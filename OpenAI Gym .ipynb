# %%
import numpy as np
import cPickle as pickle
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt
import math
import gym

# %%
env = gym.make('CartPole-v0')
# Out:
# [2017-05-24 19:19:31,656] Making new env: CartPole-v0

# %%
# env.reset()
# random_episodes = 0
# reward_sum = 0
# while random_episodes < 10:
#     env.render()
#     observation, reward, done, _ = env.step(np.random.randint(0,2))
#     reward_sum += reward
#     if done:
#         random_episodes += 1
#         print "Reward for this episode was:",reward_sum
#         reward_sum = 0
#         env.reset()

# %%
# hyperparameters
H = 10 # number of hidden layer neurons
batch_size = 5 # every how many episodes to do a param update?
learning_rate = 1e-2 # feel free to play with this to train faster or more stably.
gamma = 0.99 # discount factor for reward

D = 4 # input dimensionality

# %%
tf.reset_default_graph()

#This defines the network as it goes from taking an observation of the environment to 
#giving a probability of chosing to the action of moving left or right.
observations = tf.placeholder(tf.float32, [None,D] , name="input_x")
W1 = tf.get_variable("W1", shape=[D, H],
           initializer=tf.contrib.layers.xavier_initializer())
layer1 = tf.nn.relu(tf.matmul(observations,W1))
W2 = tf.get_variable("W2", shape=[H, 1],
           initializer=tf.contrib.layers.xavier_initializer())
score = tf.matmul(layer1,W2)
probability = tf.nn.sigmoid(score)

#From here we define the parts of the network needed for learning a good policy.
tvars = tf.trainable_variables()
input_y = tf.placeholder(tf.float32,[None,1], name="input_y")
advantages = tf.placeholder(tf.float32,name="reward_signal")

# The loss function. This sends the weights in the direction of making actions 
# that gave good advantage (reward over time) more likely, and actions that didn't less likely.
loglik = tf.log(input_y*(input_y - probability) + (1 - input_y)*(input_y + probability))
loss = -tf.reduce_mean(loglik * advantages) 
newGrads = tf.gradients(loss,tvars)

# Once we have collected a series of gradients from multiple episodes, we apply them.
# We don't just apply gradeients after every episode in order to account for noise in the reward signal.
adam = tf.train.AdamOptimizer(learning_rate=learning_rate) # Our optimizer
W1Grad = tf.placeholder(tf.float32,name="batch_grad1") # Placeholders to send the final gradients through when we update.
W2Grad = tf.placeholder(tf.float32,name="batch_grad2")
batchGrad = [W1Grad,W2Grad]
updateGrads = adam.apply_gradients(zip(batchGrad,tvars))

# %%
def discount_rewards(r):
    """ take 1D float array of rewards and compute discounted reward """
    discounted_r = np.zeros_like(r)
    running_add = 0
    for t in reversed(xrange(0, r.size)):
        running_add = running_add * gamma + r[t]
        discounted_r[t] = running_add
    return discounted_r

# %%
xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[]
running_reward = None
reward_sum = 0
episode_number = 1
total_episodes = 10000
init = tf.global_variables_initializer()

# Launch the graph
with tf.Session() as sess:
    rendering = False
    sess.run(init)
    observation = env.reset() # Obtain an initial observation of the environment

    # Reset the gradient placeholder. We will collect gradients in 
    # gradBuffer until we are ready to update our policy network. 
    gradBuffer = sess.run(tvars)
    for ix,grad in enumerate(gradBuffer):
        gradBuffer[ix] = grad * 0
    
    while episode_number <= total_episodes:
        
        # Rendering the environment slows things down, 
        # so let's only look at it once our agent is doing a good job.
        if reward_sum/batch_size > 100 or rendering == True : 
            env.render()
            rendering = True
            
        # Make sure the observation is in a shape the network can handle.
        x = np.reshape(observation,[1,D])
        
        # Run the policy network and get an action to take. 
        tfprob = sess.run(probability,feed_dict={observations: x})
        action = 1 if np.random.uniform() < tfprob else 0
        
        xs.append(x) # observation
        y = 1 if action == 0 else 0 # a "fake label"
        ys.append(y)

        # step the environment and get new measurements
        observation, reward, done, info = env.step(action)
        reward_sum += reward

        drs.append(reward) # record reward (has to be done after we call step() to get reward for previous action)

        if done: 
            episode_number += 1
            # stack together all inputs, hidden states, action gradients, and rewards for this episode
            epx = np.vstack(xs)
            epy = np.vstack(ys)
            epr = np.vstack(drs)
            tfp = tfps
            xs,hs,dlogps,drs,ys,tfps = [],[],[],[],[],[] # reset array memory

            # compute the discounted reward backwards through time
            discounted_epr = discount_rewards(epr)
            # size the rewards to be unit normal (helps control the gradient estimator variance)
            discounted_epr -= np.mean(discounted_epr)
            discounted_epr /= np.std(discounted_epr)
            
            # Get the gradient for this episode, and save it in the gradBuffer
            tGrad = sess.run(newGrads,feed_dict={observations: epx, input_y: epy, advantages: discounted_epr})
            for ix,grad in enumerate(tGrad):
                gradBuffer[ix] += grad
                
            # If we have completed enough episodes, then update the policy network with our gradients.
            if episode_number % batch_size == 0: 
                sess.run(updateGrads,feed_dict={W1Grad: gradBuffer[0],W2Grad:gradBuffer[1]})
                for ix,grad in enumerate(gradBuffer):
                    gradBuffer[ix] = grad * 0
                
                # Give a summary of how well our network is doing for each batch of episodes.
                running_reward = reward_sum if running_reward is None else running_reward * 0.99 + reward_sum * 0.01
                print 'Average reward for episode %f.  Total average reward %f.' % (reward_sum/batch_size, running_reward/batch_size)
                
                if reward_sum/batch_size > 200: 
                    print "Task solved in",episode_number,'episodes!'
                    break
                    
                reward_sum = 0
            
            observation = env.reset()
        
print episode_number,'Episodes completed.'
# Out:
# Average reward for episode 19.600000.  Total average reward 19.600000.
# Average reward for episode 34.400000.  Total average reward 19.748000.
# Average reward for episode 30.400000.  Total average reward 19.854520.
# Average reward for episode 28.400000.  Total average reward 19.939975.
# Average reward for episode 50.600000.  Total average reward 20.246575.
# Average reward for episode 19.600000.  Total average reward 20.240109.
# Average reward for episode 21.800000.  Total average reward 20.255708.
# Average reward for episode 30.800000.  Total average reward 20.361151.
# Average reward for episode 35.200000.  Total average reward 20.509540.
# Average reward for episode 33.200000.  Total average reward 20.636444.
# Average reward for episode 26.200000.  Total average reward 20.692080.
# Average reward for episode 30.400000.  Total average reward 20.789159.
# Average reward for episode 27.800000.  Total average reward 20.859267.
# Average reward for episode 23.600000.  Total average reward 20.886675.
# Average reward for episode 34.200000.  Total average reward 21.019808.
# Average reward for episode 32.000000.  Total average reward 21.129610.
# Average reward for episode 36.800000.  Total average reward 21.286314.
# Average reward for episode 37.600000.  Total average reward 21.449451.
# Average reward for episode 34.600000.  Total average reward 21.580956.
# Average reward for episode 37.800000.  Total average reward 21.743147.
# Average reward for episode 29.400000.  Total average reward 21.819715.
# Average reward for episode 28.800000.  Total average reward 21.889518.
# Average reward for episode 32.000000.  Total average reward 21.990623.
# Average reward for episode 60.400000.  Total average reward 22.374717.
# Average reward for episode 30.400000.  Total average reward 22.454969.
# Average reward for episode 30.600000.  Total average reward 22.536420.
# Average reward for episode 27.400000.  Total average reward 22.585056.
# Average reward for episode 46.400000.  Total average reward 22.823205.
# Average reward for episode 34.400000.  Total average reward 22.938973.
# Average reward for episode 43.800000.  Total average reward 23.147583.
# Average reward for episode 28.400000.  Total average reward 23.200107.
# Average reward for episode 38.400000.  Total average reward 23.352106.
# Average reward for episode 44.200000.  Total average reward 23.560585.
# Average reward for episode 59.000000.  Total average reward 23.914979.
# Average reward for episode 44.600000.  Total average reward 24.121830.
# Average reward for episode 65.400000.  Total average reward 24.534611.
# Average reward for episode 52.000000.  Total average reward 24.809265.
# Average reward for episode 34.200000.  Total average reward 24.903172.
# Average reward for episode 32.800000.  Total average reward 24.982141.
# Average reward for episode 35.200000.  Total average reward 25.084319.
# Average reward for episode 35.800000.  Total average reward 25.191476.
# Average reward for episode 40.600000.  Total average reward 25.345561.
# Average reward for episode 34.000000.  Total average reward 25.432106.
# Average reward for episode 32.600000.  Total average reward 25.503785.
# Average reward for episode 31.000000.  Total average reward 25.558747.
# Average reward for episode 33.800000.  Total average reward 25.641159.
# Average reward for episode 69.200000.  Total average reward 26.076748.
# Average reward for episode 40.400000.  Total average reward 26.219980.
# Average reward for episode 54.600000.  Total average reward 26.503781.
# Average reward for episode 42.600000.  Total average reward 26.664743.
# Average reward for episode 35.000000.  Total average reward 26.748095.
# Average reward for episode 73.600000.  Total average reward 27.216614.
# Average reward for episode 78.200000.  Total average reward 27.726448.
# Average reward for episode 34.400000.  Total average reward 27.793184.
# Average reward for episode 70.000000.  Total average reward 28.215252.
# Average reward for episode 53.000000.  Total average reward 28.463099.
# Average reward for episode 31.400000.  Total average reward 28.492468.
# Average reward for episode 37.600000.  Total average reward 28.583544.
# Average reward for episode 24.600000.  Total average reward 28.543708.
# Average reward for episode 57.200000.  Total average reward 28.830271.
# Average reward for episode 55.200000.  Total average reward 29.093968.
# Average reward for episode 64.400000.  Total average reward 29.447029.
# Average reward for episode 59.800000.  Total average reward 29.750558.
# Average reward for episode 50.200000.  Total average reward 29.955053.
# Average reward for episode 57.800000.  Total average reward 30.233502.
# Average reward for episode 73.400000.  Total average reward 30.665167.
# Average reward for episode 38.400000.  Total average reward 30.742516.
# Average reward for episode 62.800000.  Total average reward 31.063091.
# Average reward for episode 65.600000.  Total average reward 31.408460.
# Average reward for episode 58.200000.  Total average reward 31.676375.
# Average reward for episode 98.200000.  Total average reward 32.341611.
# Average reward for episode 75.400000.  Total average reward 32.772195.
# Average reward for episode 50.400000.  Total average reward 32.948473.
# Average reward for episode 69.600000.  Total average reward 33.314988.
# Average reward for episode 98.800000.  Total average reward 33.969839.
# Average reward for episode 70.400000.  Total average reward 34.334140.
# Average reward for episode 98.200000.  Total average reward 34.972799.
# Average reward for episode 88.400000.  Total average reward 35.507071.
# Average reward for episode 66.000000.  Total average reward 35.812000.
# Average reward for episode 42.000000.  Total average reward 35.873880.
# Average reward for episode 77.800000.  Total average reward 36.293141.
# Average reward for episode 41.800000.  Total average reward 36.348210.
# Average reward for episode 65.000000.  Total average reward 36.634728.
# Average reward for episode 99.600000.  Total average reward 37.264381.
# Average reward for episode 43.000000.  Total average reward 37.321737.
# Average reward for episode 83.400000.  Total average reward 37.782519.
# Average reward for episode 91.000000.  Total average reward 38.314694.
# Average reward for episode 122.200000.  Total average reward 39.153547.
# Average reward for episode 99.200000.  Total average reward 39.754012.
# Average reward for episode 63.800000.  Total average reward 39.994472.
# Average reward for episode 99.600000.  Total average reward 40.590527.
# Average reward for episode 99.400000.  Total average reward 41.178622.
# Average reward for episode 67.200000.  Total average reward 41.438835.
# Average reward for episode 83.400000.  Total average reward 41.858447.
# Average reward for episode 116.800000.  Total average reward 42.607863.
# Average reward for episode 86.200000.  Total average reward 43.043784.
# Average reward for episode 128.600000.  Total average reward 43.899346.
# Average reward for episode 72.000000.  Total average reward 44.180353.
# Average reward for episode 94.000000.  Total average reward 44.678549.
# Average reward for episode 77.200000.  Total average reward 45.003764.
# Average reward for episode 102.000000.  Total average reward 45.573726.
# Average reward for episode 106.000000.  Total average reward 46.177989.
# Average reward for episode 71.600000.  Total average reward 46.432209.
# Average reward for episode 122.200000.  Total average reward 47.189887.
# Average reward for episode 115.200000.  Total average reward 47.869988.
# Average reward for episode 137.600000.  Total average reward 48.767288.
# Average reward for episode 77.800000.  Total average reward 49.057615.
# Average reward for episode 110.800000.  Total average reward 49.675039.
# Average reward for episode 107.000000.  Total average reward 50.248289.
# Average reward for episode 90.800000.  Total average reward 50.653806.
# Average reward for episode 121.600000.  Total average reward 51.363268.
# Average reward for episode 100.400000.  Total average reward 51.853635.
# Average reward for episode 109.000000.  Total average reward 52.425099.
# Average reward for episode 94.800000.  Total average reward 52.848848.
# Average reward for episode 94.200000.  Total average reward 53.262359.
# Average reward for episode 103.000000.  Total average reward 53.759736.
# Average reward for episode 105.800000.  Total average reward 54.280138.
# Average reward for episode 140.000000.  Total average reward 55.137337.
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# <ipython-input-7-e62f808b135c> in <module>()
#      23         # so let's only look at it once our agent is doing a good job.
#      24         if reward_sum/batch_size > 100 or rendering == True :
# ---> 25             env.render()
#      26             rendering = True
#      27
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in render(self, mode, close)
#     151             elif mode not in modes:
#     152                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 153         return self._render(mode=mode, close=close)
#     154
#     155     def close(self):
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in _render(self, mode, close)
#     283
#     284     def _render(self, mode='human', close=False):
# --> 285         return self.env.render(mode, close)
#     286
#     287     def _close(self):
#
# /usr/local/lib/python2.7/dist-packages/gym/core.pyc in render(self, mode, close)
#     151             elif mode not in modes:
#     152                 raise error.UnsupportedMode('Unsupported rendering mode: {}. (Supported modes for {}: {})'.format(mode, self, modes))
# --> 153         return self._render(mode=mode, close=close)
#     154
#     155     def close(self):
#
# /usr/local/lib/python2.7/dist-packages/gym/envs/classic_control/cartpole.pyc in _render(self, mode, close)
#     143         self.poletrans.set_rotation(-x[2])
#     144
# --> 145         return self.viewer.render(return_rgb_array = mode=='rgb_array')
#
# /usr/local/lib/python2.7/dist-packages/gym/envs/classic_control/rendering.pyc in render(self, return_rgb_array)
#      82         self.window.clear()
#      83         self.window.switch_to()
# ---> 84         self.window.dispatch_events()
#      85         self.transform.enable()
#      86         for geom in self.geoms:
#
# /usr/local/lib/python2.7/dist-packages/pyglet/window/xlib/__init__.pyc in dispatch_events(self)
#     851         # Check for the events specific to this window
#     852         while xlib.XCheckWindowEvent(_x_display, _window,
# --> 853                                      0x1ffffff, byref(e)):
#     854             # Key events are filtered by the xlib window event
#     855             # handler so they get a shot at the prefiltered event.
#
# ArgumentError: argument 2: <type 'exceptions.TypeError'>: wrong type
